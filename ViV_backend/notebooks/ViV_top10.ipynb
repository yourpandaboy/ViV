# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/home/nortycute/code/yourpandaboy/ViV/df_final_cleaned.csv")

# %%
from ViV_backend.matcher import Matcher
# Out:
# 2022-08-08 13:07:02.414178: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-08 13:07:02.414252: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-08 13:07:03.859635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-08-08 13:07:03.862911: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
tmp_user = Matcher('looking for someone to scroll endlessly through netflix. Or to yell out songs at the nearest karaoke. I enjoy cooking, travelling, singing, karaoke, gaming.').user_topic()

# %%
tmp_matches = Matcher('looking for someone to scroll endlessly through netflix. Or to yell out songs at the nearest karaoke. I enjoy cooking, travelling, singing, karaoke, gaming.').output_matches()

# %%
tmp_user['5_more'] = tmp_user['Score'] * 1.05

# %%
tmp_user['5_less'] = tmp_user['Score'] * 0.95

# %%
tmp_matches
# Out:
#        Dominant_Topic  Topic_Perc_Contrib  \
# 1                 6.0              0.0916
# 30                6.0              0.0529
# 41               13.0              0.1087
# 51                4.0              0.1568
# 63                4.0              0.1269
# ...               ...                 ...
# 54428             6.0              0.0816
# 54434             4.0              0.1208
# 54437             6.0              0.0991
# 54446            13.0              0.0852
# 54451            13.0              0.1172
#
#                                                 Keywords  \
# 1      guy, fun, pretty, good, friend, person, meet, ...
# 30     guy, fun, pretty, good, friend, person, meet, ...
# 41     love, friend, family, great, good, life, close...
# 51     open, honest, kind, good, passionate, person, ...
# 63     open, honest, kind, good, passionate, person, ...
# ...                                                  ...
# ...

# %%
tmp_user
# Out:
#     Dominant_No     Score    5_more    5_less
# 12           13  0.075372  0.079141  0.071604
# 18           19  0.074685  0.078419  0.070951
# 5             6  0.053728  0.056414  0.051041
# 3             4  0.051260  0.053823  0.048697

# %%
topics = [13,19,6,4]
bounds = [0.075366,0.074698,0.053722,0.051259]

# %%
dfs = []
for topic, bound in zip(topics, bounds):
    df = tmp_matches[tmp_matches['Dominant_Topic']==topic][(tmp_matches['Topic_Perc_Contrib'] >= bound*.95) & (tmp_matches['Topic_Perc_Contrib'] <= bound*1.05)]
    
    #if df.shape[0] != 0:
        #dfs.append(df)
    dfs.append(df)
best_matches = pd.concat(dfs)
# Out:
# /tmp/ipykernel_2798/159530656.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = tmp_matches[tmp_matches['Dominant_Topic']==topic][(tmp_matches['Topic_Perc_Contrib'] >= bound*.95) & (tmp_matches['Topic_Perc_Contrib'] <= bound*1.05)]

# %%
best_matches
# Out:
#        Dominant_Topic  Topic_Perc_Contrib  \
# 317              13.0              0.0745
# 561              13.0              0.0735
# 583              13.0              0.0727
# 630              13.0              0.0780
# 1094             13.0              0.0776
# ...               ...                 ...
# 53762             6.0              0.0527
# 53786             6.0              0.0529
# 53825             6.0              0.0527
# 54160             6.0              0.0527
# 54398             6.0              0.0527
#
#                                                 Keywords  \
# 317    love, friend, family, great, good, life, close...
# 561    love, friend, family, great, good, life, close...
# 583    love, friend, family, great, good, life, close...
# 630    love, friend, family, great, good, life, close...
# 1094   love, friend, family, great, good, life, close...
# ...                                                  ...
# ...

# %%
# !git add .

# %%
# !git commit -m 'did best_matches function, able to return best matches within 10% range'
# Out:
# [norty2 76c0e94] did best_matches function, able to return best matches within 10% range
#  2 files changed, 1297 insertions(+), 11 deletions(-)
#  create mode 100644 ViV_backend/notebooks/ViV_top10.ipynb

# %%
# !git push origin norty2
# Out:
# ...
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 5.75 KiB | 2.87 MiB/s, done.
# Total 6 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# To github.com:yourpandaboy/ViV.git
#    9352c49..76c0e94  norty2 -> norty2

# %%
# !gh browse
# Out:
# Opening github.com/yourpandaboy/ViV in your browser.
#
#
# A new release of gh is available: 2.14.2 → 2.14.3
# https://github.com/cli/cli/releases/tag/v2.14.3

# %%
tmp_matches[tmp_matches['Dominant_Topic']==topic][(tmp_matches['Topic_Perc_Contrib'] >= bound*.95) & (tmp_matches['Topic_Perc_Contrib'] <= bound*1.05)]
#['Topic_Perc_Contrib'].between(bound*.95,bound*.95)
# Out:
# /tmp/ipykernel_532/25632501.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tmp_matches[tmp_matches['Dominant_Topic']==topic][(tmp_matches['Topic_Perc_Contrib'] >= bound*.95) & (tmp_matches['Topic_Perc_Contrib'] <= bound*1.05)]
#        Dominant_Topic  Topic_Perc_Contrib  \
# 985               4.0              0.0734
# 2025              4.0              0.0730
# 2151              4.0              0.0686
# 2349              4.0              0.0711
# 2675              4.0              0.0732
# ...               ...                 ...
# 53010             4.0              0.0667
# 53270             4.0              0.0709
# 53575             4.0              0.0698
# 53715             4.0              0.0709
# 53817             4.0              0.0697
#
#                                                 Keywords  \
# 985    open, honest, kind, good, passionate, person, ...
# 2025   open, honest, kind, good, passionate, person, ...
# ...

# %%
df[(df['Topic_Perc_Contrib'] >= bound*.95) & (df['Topic_Perc_Contrib'] <= bound*1.05)]
# Out:
# Empty DataFrame
# Columns: [Dominant_Topic, Topic_Perc_Contrib, Keywords, Text_x, age, status, sex, location]
# Index: []

# %%
tmp_matches
# Out:
#        Dominant_Topic  Topic_Perc_Contrib  \
# 1                 6.0              0.0916
# 30                6.0              0.0529
# 41               13.0              0.1087
# 51                4.0              0.1568
# 63                4.0              0.1269
# ...               ...                 ...
# 54428             6.0              0.0816
# 54434             4.0              0.1208
# 54437             6.0              0.0991
# 54446            13.0              0.0852
# 54451            13.0              0.1172
#
#                                                 Keywords  \
# 1      guy, fun, pretty, good, friend, person, meet, ...
# 30     guy, fun, pretty, good, friend, person, meet, ...
# 41     love, friend, family, great, good, life, close...
# 51     open, honest, kind, good, passionate, person, ...
# 63     open, honest, kind, good, passionate, person, ...
# ...                                                  ...
# ...

# %%
f =df[(df['Dominant_Topic'] == 6) & (df['Topic_Perc_Contrib'] > 0.051036) & (df['Topic_Perc_Contrib'] < 0.056408) & (df['sex'] == 2)]

# %%
u =df[(df['Dominant_Topic'] == 13) & (df['Topic_Perc_Contrib'] > 0.071597) & (df['Topic_Perc_Contrib'] < 0.079134) & (df['sex'] == 2)]

# %%
def within_range():
    pass

# %%
pd.concat([f,u])
# Out:
#        Dominant_Topic  Topic_Perc_Contrib  \
# 1064              6.0              0.0528
# 1385              6.0              0.0528
# 1967              6.0              0.0527
# 2397              6.0              0.0527
# 2652              6.0              0.0528
# ...               ...                 ...
# 49083            13.0              0.0751
# 49701            13.0              0.0769
# 51120            13.0              0.0775
# 51762            13.0              0.0745
# 52339            13.0              0.0741
#
#                                                 Keywords  \
# 1064   guy, fun, pretty, good, friend, person, meet, ...
# 1385   guy, fun, pretty, good, friend, person, meet, ...
# 1967   guy, fun, pretty, good, friend, person, meet, ...
# 2397   guy, fun, pretty, good, friend, person, meet, ...
# 2652   guy, fun, pretty, good, friend, person, meet, ...
# ...                                                  ...
# ...
